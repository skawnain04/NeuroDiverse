# %%
# importing libraries
import pandas as pd
import glob
import os

# %%
# Use glob to find all CSV files in the current directory or specify a path
csv_files = glob.glob("/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/*_comments.csv")  # Adjust the path if needed, e.g., 'path/to/files/*.csv'


print(csv_files)
# Out:
# ['/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/ptsd_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/bpd_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/depression_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/dyslexia_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/autism_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/adhd_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/ocd_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/schizophrenia_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/anxiety_comments.csv', '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/comments/bipolar_comments.csv']

# %%
# Read and concatenate the CSV files
combined_csv = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# Save the merged CSV to a new file
combined_csv.to_csv("/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/original/posts/all_comments.csv", index=False)

print("CSV files merged successfully!")
# Out:
# CSV files merged successfully!

# %%
path = '/s/chopin/l/grad/shadaab/Documents/NeuroDiverseDataset/NeuroDiverse/Data/all_posts.csv'
df = pd.read_csv(path)
df
# Out:
#      Neurodiversity                  Posted By                    Employer  \
# 0            Autism  a Human Resources Manager  San Diego State University
# 1            Autism           a Vice President  San Diego State University
# 2            Autism          a Legal Assistant  San Diego State University
# 3            Autism         a Senior Chemist 1  San Diego State University
# 4            Autism               an Associate  San Diego State University
# ...             ...                        ...                         ...
# 2803     Depression         a Business Analyst  San Diego State University
# 2804     Depression         an Account Manager  San Diego State University
# 2805     Depression                        NaN  San Diego State University
# 2806     Depression                        NaN  San Diego State University
# 2807     Depression         a Data Entry Clerk  San Diego State University
#
#                         Post Type Time Posted  \
# 0                 Human Resources     a month
# 1                 Parents at Work    2 months
# 2                      Confession    8 months
# 3               The Worklife Bowl   10 months
# 4                         Big Law    4 months
# ...                           ...         ...
# 2803            Jobs in Insurance      a year
# 2804                      Finance   10 months
# 2805                   Government      a year
# 2806  Mental Health conversations      a year
# 2807                   Toxic Boss    2 months
#
#                                                 Content  Likes  Comments  \
# 0     Hi All,\nI’m looking for some advice. We have ...   16.0      57.0
# 1     Very close to pull the trigger to take 2-3 yea...   13.0      54.0
# 2     I’ve been crying for the last hour and can’t s...   12.0      27.0
# 3     I'm a 19 year old with high anxiety and depres...   14.0      20.0
# 4     Does anyone have autism in big law ? If so how...   16.0      10.0
# ...                                                 ...    ...       ...
# 2803  Started a new job 5 months ago, little did I k...    3.0       0.0
# 2804  "With a good perspective on history, we can ha...    2.0       0.0
# 2805  Monash Health and Fetish houses, have installe...    1.0       0.0
# 2806  Is it possible to get a top-secret clearance i...    NaN       0.0
# 2807  My boss took over my Office 5 years ago . She ...    NaN       0.0
#
#       Shares  Timestamp Collected  ... Post ID           hashtags diseases  \
# 0        3.0  2024-09-19 20:27:50  ...     1.0  No hashtags found   Autism
# 1        5.0  2024-09-19 20:28:33  ...     2.0  No hashtags found   Autism
# 2        1.0  2024-09-19 20:29:16  ...     3.0  No hashtags found   Autism
# 3        3.0  2024-09-19 20:29:50  ...     4.0  No hashtags found   Autism
# 4       10.0  2024-09-19 20:30:17  ...     5.0  No hashtags found   Autism
# ...      ...                  ...  ...     ...                ...      ...
# 2803     NaN        9/21/24 13:28  ...   562.0  No hashtags found  Anxiety
# 2804     NaN        9/21/24 13:28  ...   563.0  No hashtags found  Anxiety
# 2805     NaN        9/21/24 13:29  ...   564.0  No hashtags found  Unknown
# 2806     NaN        9/21/24 13:29  ...   565.0  No hashtags found  Anxiety
# 2807     NaN        9/21/24 13:30  ...   566.0  No hashtags found  Unknown
#
#      medical_advice                                topic workplace_related  \
# 0               No.              Autism in the workplace              Yes.
# 1                No                        SAHM (Stay-at               No.
# 2               No.            Autism and ADHD diagnosis               No.
# 3               No.    Social anxiety and communication.               No.
# 4               No.                    Autism in Big Law              Yes.
# ...             ...                                  ...               ...
# 2803            No.              Toxic work environment.              Yes.
# 2804            No.  Historical perspective in investing               No.
# 2805            No.                          Problematic       Problematic
# 2806            No.      Top-secret clearance and mental              Yes.
# 2807            No.              Toxic work environment.              Yes.
#
#      medical_medicine_related discrimination medicine_related  \
# 0                         No.            No.               No
# 1                         No.            No.              No.
# 2                         No.            No.              No.
# 3                         No.            No.              No.
# 4                         No.            No.              No.
# ...                       ...            ...              ...
# 2803                      No.            No.              No.
# 2804                      No.            No.              No.
# 2805              Problematic            No.              No.
# 2806                      No.            No.               No
# 2807                      No.            No.              No.
#
#      relational_challenges
# 0                      No.
# 1                      No.
# 2                      No.
# 3                     Yes.
# 4                      No.
# ...                    ...
# 2803                   No.
# 2804                   No.
# 2805                   No.
# 2806                   No.
# 2807                   No.
#
# [2808 rows x 21 columns]

# %%
df.dropna(subset=["Content"], inplace=True)
df.to_csv(path, index=False)

# %%
df
# Out:
#       Neurodiversity Posted By                                     Employer  \
# 0               PTSD     Other                                 CareSource 1
# 1               PTSD     Other             a Business Development Manager 1
# 2               PTSD     Other                          a Finance Analyst 1
# 3               PTSD     Other                          a Finance Analyst 1
# 4               PTSD    Author  Authora Customer Service Representative CSR
# ...              ...       ...                                          ...
# 29938        Bipolar     Other                         a Freelance Writer 1
# 29939        Bipolar     Other                    Authora Developer Analyst
# 29940        Bipolar     Other                         an Account Manager 1
# 29941        Bipolar     Other                                   Deloitte 1
# 29942        Bipolar     Other                          an ACD Copywriter 1
#
#       Time Posted                                            Content  \
# 0        4 months  But imagine applying and getting an interview ...
# 1        4 months  Really!!!! So true… or you are fully qualified...
# 2        4 months  Job requirements be like?\nFirst you might try...
# 3        4 months    Sorry 17 year stroke survivor; you get my gist!
# 4        4 months  This was supposed to be a joke 🤣 no idea why h...
# ...           ...                                                ...
# 29938      a year  Not sure what being upset or “raging out” have...
# 29939      a year  She is diagnosed i was never diagnosed it was ...
# 29940         22d  Foreal, imagine how many years the Gallaghers ...
# 29941         22d  Sorry OP. You might have better luck phrasing ...
# 29942    5 months          Hi, what kind of job are you looking for?
#
#            Reactions Timestamp Collected  \
# 0                 12       9/20/24 12:39
# 1                  9       9/20/24 12:39
# 2                  6       9/20/24 12:39
# 3       3\nreactions       9/20/24 12:39
# 4      25\nreactions       9/20/24 12:39
# ...              ...                 ...
# 29938            NaN       9/20/24 10:48
# 29939            NaN       9/20/24 10:48
# 29940            NaN       9/20/24 10:49
# 29941            NaN       9/20/24 10:49
# 29942            NaN       9/20/24 11:12
#
#                                                 Post URL  Hierarchy  Post ID  \
# 0      https://www.fishbowlapp.com/post/job-hunting-p...        1.0      1.0
# 1      https://www.fishbowlapp.com/post/job-hunting-p...        1.0      1.0
# 2      https://www.fishbowlapp.com/post/job-hunting-p...        1.0      1.0
# 3      https://www.fishbowlapp.com/post/job-hunting-p...        2.0      1.0
# 4      https://www.fishbowlapp.com/post/job-hunting-p...        3.0      1.0
# ...                                                  ...        ...      ...
# 29938  https://www.fishbowlapp.com/post/i-have-an-aun...        1.0     35.0
# 29939  https://www.fishbowlapp.com/post/i-have-an-aun...        1.0     35.0
# 29940  https://www.fishbowlapp.com/post/living-with-b...        1.0     36.0
# 29941  https://www.fishbowlapp.com/post/living-with-b...        1.0     36.0
# 29942  https://www.fishbowlapp.com/post/ive-dealt-wit...        1.0     41.0
#
#        Comment ID  \
# 0             1.0
# 1             2.0
# 2             3.0
# 3             4.0
# 4             5.0
# ...           ...
# 29938       538.0
# 29939       539.0
# 29940       540.0
# 29941       541.0
# 29942       542.0
#
#        Neurodiversity\tPosted By\tEmployer\tTime Posted\tContent\tReactions\tTimestamp Collected\tPost URL\tHierarchy\tPost ID\tComment ID  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29938                                                NaN
# 29939                                                NaN
# 29940                                                NaN
# 29941                                                NaN
# 29942                                                NaN
#
#                 hashtags
# 0      No hashtags found
# 1      No hashtags found
# 2      No hashtags found
# 3      No hashtags found
# 4      No hashtags found
# ...                  ...
# 29938  No hashtags found
# 29939  No hashtags found
# 29940  No hashtags found
# 29941  No hashtags found
# 29942  No hashtags found
#
# [29943 rows x 13 columns]

# %%
list(df.columns)
# Out:
# ['Neurodiversity',
#  'Posted By',
#  'Employer',
#  'Post Type',
#  'Time Posted',
#  'Content',
#  'Likes',
#  'Comments',
#  'Shares',
#  'Timestamp Collected',
#  'Post URL',
#  'Post ID',
#  'hashtags',
#  'diseases']

# %%
df.rename(columns={'medical_advice_y': 'medical_advice'}, inplace=True)

# %%
df.drop('Neurodiversity\tPosted By\tEmployer\tPost Type\tTime Posted\tContent\tLikes\tComments\tShares\tTimestamp Collected\tPost URL\tPost ID', axis=1, inplace=True)

# %%
df.to_csv(path, index=False)

# %%
#posts
df_0_p = pd.read_csv("anxiety_posts_merged.csv")
df_1_p = pd.read_csv("anxiety_posts_V1.csv")
df_2_p = pd.read_csv("anxiety_posts_V2.csv")
df_3_p = pd.read_csv("anxiety_posts_V3.csv")
df_4_p = pd.read_csv("anxiety_posts_V4.csv")
df_5_p = pd.read_csv("anxiety_posts_V5.csv")
df_6_p = pd.read_csv("anxiety_posts_V6.csv")
df_7_p = pd.read_csv("anxiety_posts_V7.csv")
df_8_p = pd.read_csv("anxiety_posts_V8.csv")
df_9_p = pd.read_csv("anxiety_posts_V9.csv")

#comments
df_0_c = pd.read_csv("anxiety_comments_merged.csv")
df_1_c = pd.read_csv("anxiety_comments_V1.csv")
df_2_c = pd.read_csv("anxiety_comments_V2.csv")
df_3_c = pd.read_csv("anxiety_comments_V3.csv")
df_4_c = pd.read_csv("anxiety_comments_V4.csv")
df_5_c = pd.read_csv("anxiety_comments_V5.csv")
df_6_c = pd.read_csv("anxiety_comments_V6.csv")
df_7_c = pd.read_csv("anxiety_comments_V7.csv")
df_8_c = pd.read_csv("anxiety_comments_V8.csv")
df_9_c = pd.read_csv("anxiety_comments_V9.csv")

# %%
# Finally, the files are joined
df_p = pd.concat([df_0_p, df_1_p, df_2_p, df_3_p, df_4_p, df_5_p, df_6_p, df_7_p, df_8_p, df_9_p], ignore_index=True)
print(df_p)
# Out:
#      Neurodiversity Posted By                  Employer Time Posted  \
# 0           Anxiety     Other            an Associate 1    4 months
# 1           Anxiety     Other            an Associate 3    4 months
# 2           Anxiety     Other            an Associate 1    4 months
# 3           Anxiety     Other             an Attorney 1    4 months
# 4           Anxiety     Other            an Associate 2    4 months
# ...             ...       ...                       ...         ...
# 5673        Anxiety     Other           Goldman Sachs 1    6 months
# 5674        Anxiety    Author  Authora Graphic Designer    6 months
# 5675        Anxiety    Author  Authora Graphic Designer    6 months
# 5676        Anxiety    Author                a Broker 1    6 months
# 5677        Anxiety    Author       a Claims Adjuster 1    5 months
#
#                                                 Content Reactions  \
# 0                                         No you’re not        53
# 1     Is the frog a failure for jumping out of the p...        48
# 2     Consider you might also be entitled to medical...        23
# 3     No! It's never a failure to realize you can't ...        28
# 4     No, big law is very hard and most people leave...        31
# ...                                                 ...       ...
# 5673  and most women want to marry men, what does th...       NaN
# 5674                                        Thank you 👏       NaN
# 5675                                        Thank you 👏       NaN
# 5676  You should probably NOT walk near people as th...       NaN
# 5677  Just keep 6’ distance from everyone and you wo...         1
#
#       Timestamp Collected                                           Post URL  \
# 0         9/16/2024 22:44  https://www.fishbowlapp.com/post/am-i-a-failur...
# 1         9/16/2024 22:44  https://www.fishbowlapp.com/post/am-i-a-failur...
# 2         9/16/2024 22:44  https://www.fishbowlapp.com/post/am-i-a-failur...
# 3         9/16/2024 22:44  https://www.fishbowlapp.com/post/am-i-a-failur...
# 4         9/16/2024 22:44  https://www.fishbowlapp.com/post/am-i-a-failur...
# ...                   ...                                                ...
# 5673  2024-09-17 12:07:14  https://www.fishbowlapp.com/post/27f-ever-sinc...
# 5674  2024-09-17 12:07:14  https://www.fishbowlapp.com/post/27f-ever-sinc...
# 5675  2024-09-17 12:07:14  https://www.fishbowlapp.com/post/27f-ever-sinc...
# 5676  2024-09-17 12:07:14  https://www.fishbowlapp.com/post/27f-ever-sinc...
# 5677  2024-09-17 12:07:14  https://www.fishbowlapp.com/post/27f-ever-sinc...
#
#       Hierarchy  Post ID  Comment ID
# 0             1        2           1
# 1             1        2           2
# 2             1        2           3
# 3             1        2           4
# 4             1        2           5
# ...         ...      ...         ...
# 5673          3      196         120
# 5674          4      196         121
# 5675          1      196         122
# 5676          1      196         123
# 5677          1      196         124
#
# [5678 rows x 11 columns]

# %%
df_c = pd.concat([df_0_c, df_1_c, df_2_c, df_3_c, df_4_c, df_5_c, df_6_c, df_7_c, df_8_c, df_9_c], ignore_index=True)
print(df_c)

# %%
df_p.count()
# Out:
# Neurodiversity         5678
# Posted By              5678
# Employer               5516
# Time Posted            5678
# Content                5663
# Reactions              4062
# Timestamp Collected    5678
# Post URL               5678
# Hierarchy              5678
# Post ID                5678
# Comment ID             5678
# dtype: int64

# %%
df_c.count()

# %%
df_p.to_csv("anxiety_posts_merged.csv", index=False)
df_c.to_csv("anxiety_comments_merged.csv", index=False)
